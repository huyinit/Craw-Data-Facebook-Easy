# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # tải thư viện và import thư viện

# %%
# %pip install facebook_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: facebook_scraper in /usr/local/lib/python3.7/dist-packages (0.2.59)
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from facebook_scraper) (1.1.1)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from facebook_scraper) (0.10.0)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from facebook_scraper) (3.0.5)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,<2022.3.15 in /usr/local/lib/python3.7/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2022.3.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2022.2.1)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.4.3)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (0.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.0.2)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (0.1.11)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2022.6.15)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.25.11)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.12.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.9.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser<2.0.0,>=1.0.0->facebook_scraper) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.10)

# %%
# Import thư viện cần thiết
from facebook_scraper import get_posts
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # bắt đầu cào post từ 1 page của Facebook

# %%
FANPAGE_LINK ="usuktimes"
FOLDER_PATH = "/content/drive/MyDrive/Tài liệu năm 4/kì 1/NMKHDL/kiemtra/"
COOKIE_PATH = "/content/drive/MyDrive/Tài liệu năm 4/kì 1/NMKHDL/kiemtra/facebookcom_cookies1.txt"

PAGES_NUMBER = 10 # số trang cần cào

# %%
from facebook_scraper import get_posts
import pandas as pd

# %%
post_list = []
for post in get_posts(FANPAGE_LINK, 
                    options={"comments": True, "reactions": True, "allow_extra_requests": True}, 
                    extra_info=True, pages=10, cookies=COOKIE_PATH):
    post_list.append(post)
# Out:
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_video didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_video_thumbnail didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_video_id didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_factcheck didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_share_information didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_listing didn't return anything
# WARNING:facebook_scraper.extractors:[621831346134146] Extract method extract_with didn't return anything
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"621831346134146_597835655158060"}' id='597835655158060' data-uniqueid='597835655158060' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 8'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"621831346134146_765685481358597"}' id='765685481358597' data-uniqueid='765685481358597' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 33'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i', '_2a_l') data-store='{"token":"621831346134146_901573394146562"}' id='901573394146562' data-uniqueid='901573394146562' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 43'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i', '_2a_l') data-store='{"token":"621831346134146_455560596506668"}' id='455560596506668' data-uniqueid='455560596506668' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 98'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"621831346134146_1430599974087342"}' id='1430599974087342' data-uniqueid='1430599974087342' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 21'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"621831346134146_3253268481578905"}' id='3253268481578905' data-uniqueid='3253268481578905' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 9'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i', '_2a_l') data-store='{"token":"621831346134146_2368351436660418"}' id='2368351436660418' data-uniqueid='2368351436660418' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 4'
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_video didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_video_thumbnail didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_video_id didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_factcheck didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_share_information didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_listing didn't return anything
# WARNING:facebook_scraper.extractors:[621301309520483] Extract method extract_with didn't return anything
# WARNING:facebook_scraper.extractors:No comments found on page
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_video didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_video_thumbnail didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_video_id didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_factcheck didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_share_information didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_listing didn't return anything
# WARNING:facebook_scraper.extractors:[620203652963582] Extract method extract_with didn't return anything
# /usr/local/lib/python3.7/dist-packages/facebook_scraper/facebook_scraper.py:909: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/ufi/reaction/profile/browser/fetch/?ft_ent_identifier=pfbid02oHHcDvexUm5uBJkrWXAyMPLQMSFSjvAT8objFKPezrSG2ZB19igzfhhZDWKrV48Zl&limit=50&shown_ids=100001873702345%2C100001770194532%2C100001706725201%2C100001697154635%2C100001634832273%2C100001323402577%2C100000864291387%2C100000647831540%2C100000478878807%2C100000460232936%2C100000276183191%2C100000188004926%2C100000187455346%2C100000152964458%2C1736155850%2C1342025960%2C761815061%2C100004719121085%2C100004586263529%2C100004552800937%2C100004437695184%2C100004418976117%2C100004399392329%2C100004385795512%2C100004364898125%2C100004311074102%2C100004253821730%2C100004226618610%2C100004205671814%2C100004203848233%2C100004180448557%2C100004174201686%2C100004159303649%2C100004107257513%2C100004082733555%2C100004036604981%2C100004036287557%2C100004019857834%2C100003991861845%2C100003940516194%2C
data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_558846499281801"}' id='558846499281801' data-uniqueid='558846499281801' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_695622071515407"}' id='695622071515407' data-uniqueid='695622071515407' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_1657717727922992"}' id='1657717727922992' data-uniqueid='1657717727922992' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_777997219888522"}' id='777997219888522' data-uniqueid='777997219888522' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_5595857087092616"}' id='5595857087092616' data-uniqueid='5595857087092616' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_411429924219773"}' id='411429924219773' data-uniqueid='411429924219773' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>]: invalid literal for int() with base 10: 'Tất cả 2'
# ERROR:facebook_scraper.extractors:Unable to parse comment /comment/replies/?ctoken=1177254746459536_1155974348295992&count=2&curr&pc=1&isinline&initcomp&ft_ent_identifier=pfbid02S8CiTz6MAHnPX9tVkUyoAnaZ6moWNaTq57fQppRDdgG4duhtKfQZ2PkQTzzSpcuyl&eav=Afa-461Cdqs3IW693ulwvKpvxWGLwrCBrh0T7VWJ4uts1ytdY1pK-DiIrI7RFkT8OgY&av=100077600834331&gfid=AQDqZpjPLI1_25ZEvhQ&refid=52&__tn__=R replies [<Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_2570413059756980"}' id='2570413059756980' data-uniqueid='2570413059756980' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>, <Element 'div' class=('_2a_i',) data-store='{"token":"1177254746459536_1211838406240267"}' id='1211838406240267' data-uniqueid='1211838406240267' data-gt='{"tn":"R"}' data-sigil='comment inline-reply'>]: invalid literal for int() with base 10: 'Tất cả 4'
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_video didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_video_thumbnail didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_video_id didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_factcheck didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_share_information didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_listing didn't return anything
# WARNING:facebook_scraper.extractors:[1174643956720615] Extract method extract_with didn't return anything
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/extractors.py", line 708, in extract_reactors
#     data = json.loads(response.text[prefix_length:])  # Strip 'for (;;);'
#   File "/usr/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 2 (char 1)
# ERROR:facebook_scraper.utils:Exception when consuming <generator object PostExtractor.extract_reactors at 0x7f812618d950>: <class 'json.decoder.JSONDecodeError'>: Expecting value: line 1 column 2 (char 1)
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_1017806399105640"}' id='1017806399105640' data-uniqueid='1017806399105640' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 22'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_708912327081078"}' id='708912327081078' data-uniqueid='708912327081078' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 32'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_368190425382195"}' id='368190425382195' data-uniqueid='368190425382195' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 106'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_560067518854101"}' id='560067518854101' data-uniqueid='560067518854101' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 80'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_1458444401255945"}' id='1458444401255945' data-uniqueid='1458444401255945' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 21'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_1059024171373010"}' id='1059024171373010' data-uniqueid='1059024171373010' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 44'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_445475164025511"}' id='445475164025511' data-uniqueid='445475164025511' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 34'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_1014545372588103"}' id='1014545372588103' data-uniqueid='1014545372588103' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 11'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_1129036301160951"}' id='1129036301160951' data-uniqueid='1129036301160951' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 32'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_734956791152739"}' id='734956791152739' data-uniqueid='734956791152739' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 20'
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"1174643956720615_719233952737259"}' id='719233952737259' data-uniqueid='719233952737259' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 7'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/extractors.py", line 708, in extract_reactors
#     data = json.loads(response.text[prefix_length:])  # Strip 'for (;;);'
#   File "/usr/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 2 (char 1)
# ERROR:facebook_scraper.utils:Exception when consuming <generator object PostExtractor.extract_reactors at 0x7f8125cf16d0>: <class 'json.decoder.JSONDecodeError'>: Expecting value: line 1 column 2 (char 1)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/extractors.py", line 708, in extract_reactors
#     data = json.loads(response.text[prefix_length:])  # Strip 'for (;;);'
#   File "/usr/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 2 (char 1)
# ERROR:facebook_scraper.utils:Exception when consuming <generator object PostExtractor.extract_reactors at 0x7f81262f08d0>: <class 'json.decoder.JSONDecodeError'>: Expecting value: line 1 column 2 (char 1)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/utils.py", line 279, in safe_consume
#     for item in generator:
#   File "/usr/local/lib/python3.7/dist-packages/facebook_scraper/extractors.py", line 708, in extract_reactors
#     data = json.loads(response.text[prefix_length:])  # Strip 'for (;;);'
#   File "/usr/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column
#    'text': ''}],
#  'user_id': '100049218584558',
#  'username': 'USUK TIMES',
#  'user_url': 'https://facebook.com/usuktimes?lst=100077600834331%3A100049218584558%3A1662879766&refid=17&_ft_=qid.-5631609081679701156%3Amf_story_key.621831346134146%3Atop_level_post_id.621831346134146%3Atl_objid.621831346134146%3Acontent_owner_id_new.100049218584558%3Athrowback_story_fbid.621831346134146%3Apage_id.194884918029862%3Aphoto_id.621840039466610%3Astory_location.4%3Astory_attachment_style.photo%3Aott.AX8RIninBL6hxuSE%3Aent_attachement_type.MediaAttachment%3Aapp_id.350685531728%3Apage_insights.%7B%22100049218584558%22%3A%7B%22page_id%22%3A100049218584558%2C%22page_id_type%22%3A%22page%22%2C%22actor_id%22%3A100049218584558%2C%22dm%22%3A%7B%22isShare%22%3A0%2C%22originalPostOwnerID%22%3A0%7D%2C%22psn%22%3A%22EntStatusCreationStory%22%2C%22post_context%22%3A%7B%22object_fbtype%22%3A266%2C%22publish_time%22%3A1662874428%2C%22story_name%22%3A%22EntStatusCreationStory%22%2C%22story_fbid%22%3A%5B621831346134146%5D%7D%2C%22role%22%3A1%2C%22sl%22%3A4%2C%22targets%22%3A%5B%7B%22actor_id%22%3A100049218584558%2C%22page_id%22%3A100049218584558%2C%22post_id%22%3A621831346134146%2C%22role%22%3A1%2C%22share_id%22%3A0%7D%5D%7D%7D%3Aprofile_id.100049218584558%3Aprofile_relationship_type.6%3Aactrs.100049218584558%3Atds_flgs.3%3Athid.100049218584558%3A306061129499414%3A2%3A0%3A1664607599%3A2297933970382111925%3A%3A%3Aftmd_400706.111111l&__tn__=C-R',
#  'is_live': False,
#  'factcheck': None,
#  'shared_post_id': None,
#  'shared_time': None,
#  'shared_user_id': None,
#  'shared_username': None,
#  'shared_post_url': None,
#  'available': True,
#  'comments_full': [{'comment_id': '772081764063187',
#    'comment_url': 'https://facebook.com/772081764063187',
#    'commenter_id': '105742761352785',
#    'commenter_url': 'https://facebook.com/Page-comment-dạo-105742761352785/?rc=p&refid=52&__tn__=%7ER',
#    'commenter_name': 'Page comment dạo',
#    'commenter_meta': None,
#    'comment_text': 'Ở đây người ta chê là đi quá xa so với nguyên tác thôi mà chứ đâu có phân biệt gì, còn bà nữ hoàng lên twitter cũng nhiều người chửi kinh chứ đâu phải mỗi người việt',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 6),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Quốc Đạt',
#      'link': 'https://facebook.com/profile.php?id=100010674425336&fref=pb',
#      'type': 'like'},
#     {'name': 'Hiên',
#      'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 2},
#    'comment_reaction_count': 2,
#    'replies': []},
#   {'comment_id': '458444376228586',
#    'comment_url': 'https://facebook.com/458444376228586',
#    'commenter_id': '100084513108521',
#    'commenter_url': 'https://facebook.com/profile.php?id=100084513108521&fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Mưa nào mà hổng tạnh?',
#    'commenter_meta': None,
#    'comment_text': 'T chỉ chê k hợp vai',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 11),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '612147090506524',
#    'comment_url': 'https://facebook.com/612147090506524',
#    'commenter_id': '108450644790868',
#    'commenter_url': 'https://facebook.com/Unknown-cmt-dạo-108450644790868/?rc=p&refid=52&__tn__=%7ER',
#    'commenter_name': 'Unknown cmt dạo',
#    'commenter_meta': None,
#    'comment_text': 'Biết ai bắt đầu mấy cái linh tinh này ko? Bọn phê ph\\\\ hãm loz đấy. Ko hài lòng thì có thể lên án, nhưng lani chọn giở giọng chê bôi shaming racist vđ ra. Bắt nguồn hết từ lũ phê f…ò chứ đâu',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 2),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '455933446283551',
#    'comment_url': 'https://facebook.com/455933446283551',
#    'commenter_id': '100012815145217',
#    'commenter_url': 'https://facebook.com/thanhyen.vo.758?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Võ Nguyễn Thanh Xuân',
#    'commenter_meta': None,
#    'comment_text': 'Yeah chê không đúng với nguyên tác chứ mấy người bodyshaming chỉ dữ dội quá\nDùng từ khó nghe vcl',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Đào Hữu Phúc',
#      'link': 'https://facebook.com/profile.php?id=100011314001679&fref=pb',
#      'type': 'like'},
#     {'name': 'Minh Chauu',
#      'link': 'https://facebook.com/nguyen.m.chau.376?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 2},
#    'comment_reaction_count': 2,
#    'replies': []},
#   {'comment_id': '630888685301129',
#    'comment_url': 'https://facebook.com/630888685301129',
#    'commenter_id': '100069037194802',
#    'commenter_url': 'https://facebook.com/profile.php?id=100069037194802&fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Miyawaki Nako',
#    'commenter_meta': None,
#    'comment_text': 'Thật ra ko có chê màu da, mà là chê nhan sắc của diễn viên',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 1),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Đào Hương Giang',
#      'link': 'https://facebook.com/profile.php?id=100028313640019&fref=pb',
#      'type': 'like'},
#     {'name': 'Lê Thị Bích Trâm',
#      'link': 'https://facebook.com/tram.lethibich.3158?fref=pb',
#      'type': 'like'},
#     {'name': 'Hiên',
#      'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#      'type': 'like'},
#     {'name': 'Huyền Huyền',
#      'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 4},
#    'comment_reaction_count': 4,
#    'replies': []},
#   {'comment_id': '571491394666880',
#    'comment_url': 'https://facebook.com/571491394666880',
#    'commenter_id': '100004012895331',
#    'commenter_url': 'https://facebook.com/HillyN06?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Yến Nguyễn',
#    'commenter_meta': None,
#    'comment_text': 'Chẳng phải thượng đẳng nhưng Ariel là một tượng đài đối với đa số người vì những đặc trưng của ẻm, h live action vứt cmn hết nguyên tác đi kèm theo mấy đứa cmt không mang não thì k toxic k được',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Làng Gốm bÁt TrÀg +',
#      'link': 'https://facebook.com/Làng-Gốm-bÁt-TrÀg--101818822413088/?fref=pb',
#      'type': 'like'},
#     {'name': 'Nguyen Tuan',
#      'link': 'https://facebook.com/profile.php?id=100076185171317&fref=pb',
#      'type': 'like'},
#     {'name': 'Hee Bóng Gồng',
#      'link': 'https://facebook.com/profile.php?id=100073942326570&fref=pb',
#      'type': 'like'},
#     {'name': 'Kim Sángg',
#      'link': 'https://facebook.com/ksr1408?fref=pb',
#      'type': 'like'},
#     {'name': 'Enola Pham',
#      'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#      'type': 'like'},
#     {'name': 'Hiên',
#      'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 6},
#    'comment_reaction_count': 6,
#    'replies': [{'comment_id': '1744341632591813',
#      'comment_url': 'https://facebook.com/1744341632591813',
#      'commenter_id': '100004012895331',
#      'commenter_url': 'https://facebook.com/HillyN06?fref=nf&rc=p&__tn__=R',
#      'commenter_name': 'Yến Nguyễn',
#      'commenter_meta': None,
#      'comment_text': 'Halle thử đóng Tiana xem con dân nó có tung hô bằng zời không 🙂 này cứ nhằm Ariel mà đóng thì ai chẳng cú',
#      'comment_time': datetime.datetime(2022, 9, 10, 23, 12),
#      'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#      'comment_reactors': [{'name': 'Kim Sángg',
#        'link': 'https://facebook.com/ksr1408?fref=pb',
#        'type': 'like'},
#       {'name': 'Enola Pham',
#        'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#        'type': 'like'},
#       {'name': 'Haanh Hoang',
#        'link': 'https://facebook.com/profile.php?id=100018876721453&fref=pb',
#        'type': 'like'}],
#      'comment_reactions': {'like': 3},
#      'comment_reaction_count': 3}]},
#   {'comment_id': '396151842692455',
#    'comment_url': 'https://facebook.com/396151842692455',
#    'commenter_id': '100000111721740',
#    'commenter_url': 'https://facebook.com/rapuzel.wild?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Thơm Donal',
#    'commenter_meta': None,
#    'comment_text': 'Thà đổi tên công chúa đi thì hơn bạn ah, arion hay ariri gì cũng đc, tại sao phải là Ariel, phá nát tuổi thơ của tui , tui ko có kì thi gì nhưng công chúa Ariel trong truyện là cá Koi chứ ko phải cá trắm đen ...',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 1),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Hee Bóng Gồng',
#      'link': 'https://facebook.com/profile.php?id=100073942326570&fref=pb',
#      'type': 'like'},
#     {'name': 'Hạ Nhiên',
#      'link': 'https://facebook.com/profile.php?id=100071038076902&fref=pb',
#      'type': 'like'},
#     {'name': 'Enola Pham',
#      'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#      'type': 'like'},
#     {'name': 'Minh Cheng',
#      'link': 'https://facebook.com/cheng.minh.16?fref=pb',
#      'type': 'like'},
#     {'name': 'Minh Nguỵt',
#      'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#      'type': 'like'},
#     {'name': 'Haanh Hoang',
#      'link': 'https://facebook.com/profile.php?id=100018876721453&fref=pb',
#      'type': 'like'},
#     {'name': 'Huyền Huyền',
#      'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#      'type': 'like'},
#     {'name': 'Yến Nguyễn',
#      'link': 'https://facebook.com/HillyN06?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 8},
#    'comment_reaction_count': 8,
#    'replies': []},
#   {'comment_id': '647996189899519',
#    'comment_url': 'https://facebook.com/647996189899519',
#    'commenter_id': '100070207290574',
#    'commenter_url': 'https://facebook.com/ksr1408?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Kim Sángg',
#    'commenter_meta': None,
#    'comment_text': 'Không đồng tình với những cô cậu body shaming hay pbct,màu da để chửi.Cũng không rõ Bạch Tuyết hay Ariel là người có ngoại hình như thế nào trong bản gốc,cốt truyện gốc mà mng nói.Nhưng đứng ở góc nhìn của toi từ nhỏ tới bây giờ,những bộ phim hay câu chuyện toi được coi thì Bạch Tuyết tóc đen mun bồng bềnh da trắng,nàng tiên cá tóc đỏ mắt sáng da màu sáng(nói thẳng ra là da trắng).Đấy là toi thấy,bây giờ làm phim,hình tượng nhân vật không giống trong tưởng tượng và những gì toi được biết thì toi có quyền không hài lòng và thất vọng.Đọc cmt của một số người bảo vệ quyền của người da màu nhưng nói như kiểu chúng toi kì thị chủng tộc vậy đó.Thất vọng và kì thị nó rất khác biệt mà nhỉ?',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 50),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '5630687016974423',
#    'comment_url': 'https://facebook.com/5630687016974423',
#    'commenter_id': '100015101804474',
#    'commenter_url': 'https://facebook.com/phamtuangian?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Phạm Tuấn Gian',
#    'commenter_meta': None,
#    'comment_text': 'Làm live action theo y bản gốc thì chê nhạt nhẽo, giờ Disney đổi mới thì lại chê k hợp. Mấy má mở bản 2d tự xem đi má',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 19),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '742446810389141',
#    'comment_url': 'https://facebook.com/742446810389141',
#    'commenter_id': '100033077760299',
#    'commenter_url': 'https://facebook.com/annieforabetterlife?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Bình An',
#    'commenter_meta': None,
#    'comment_text': 'Bà này đóng vai tiana của hoàng tử ếch hợp hơn',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 3),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Enola Pham',
#      'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 1},
#    'comment_reaction_count': 1,
#    'replies': []},
#   {'comment_id': '394887972634663',
#    'comment_url': 'https://facebook.com/394887972634663',
#    'commenter_id': '100010265733528',
#    'commenter_url': 'https://facebook.com/vitocvit0601?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Su An',
#    'commenter_meta': None,
#    'comment_text': 'K phải pbct nhưng bả đóng k hợp thật mà, nếu bả vào vai cc tóc xù hay Moana thì đã khác',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 7),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '1074976213390468',
#    'comment_url': 'https://facebook.com/1074976213390468',
#    'commenter_id': '100057590401565',
#    'commenter_url': 'https://facebook.com/MKhenh?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Minh Khánh',
#    'commenter_meta': None,
#    'comment_text': 'Mà bên nc ngoài nó chê trước , chê còn thậm tệ hơn , chê từ lúc film mới cast diễn viên r :))',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 56),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '600728248265291',
#    'comment_url': 'https://facebook.com/600728248265291',
#    'commenter_id': '100049821698002',
#    'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Vi',
#    'commenter_meta': None,
#    'comment_text': 'C Ariel ko đẹp thiệt=))',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 5),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Enola Pham',
#      'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 1},
#    'comment_reaction_count': 1,
#    'replies': [{'comment_id': '1149511769106636',
#      'comment_url': 'https://facebook.com/1149511769106636',
#      'commenter_id': '100064439176152',
#      'commenter_url': 'https://facebook.com/DeeneCao.Deku?fref=nf&rc=p&__tn__=R',
#      'commenter_name': 'Deene Cao',
#      'commenter_meta': None,
#      'comment_text': 'Vi ???',
#      'comment_time': datetime.datetime(2022, 9, 10, 23, 9),
#      'comment_image': None,
#      'comment_reactors': [],
#      'comment_reactions': None,
#      'comment_reaction_count': None},
#     {'comment_id': '430042945658997',
#      'comment_url': 'https://facebook.com/430042945658997',
#      'commenter_id': '100049821698002',
#      'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&__tn__=R',
#      'commenter_name': 'Vi',
#      'commenter_meta': None,
#      'comment_text': 'Deene Cao ???',
#      'comment_time': datetime.datetime(2022, 9, 10, 23, 9),
#      'comment_image': None,
#      'comment_reactors': [],
#      'comment_reactions': None,
#      'comment_reaction_count': None},
#     {'comment_id': '479556584185612',
#      'comment_url': 'https://facebook.com/479556584185612',
#      'commenter_id': '100064439176152',
#      'commenter_url': 'https://facebook.com/DeeneCao.Deku?fref=nf&rc=p&__tn__=R',
#      'commenter_name': 'Deene Cao',
#      'commenter_meta': None,
#      'comment_text': 'Vi Không phải là không đẹp chỉ là không hợp vai côg chúa này thôi chứ?',
#      'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#      'comment_image': None,
#      'comment_reactors': [],
#      'comment_reactions': None,
#      'comment_reaction_count': None},
#     {'comment_id': '1227875141342859',
#      'comment_url': 'https://facebook.com/1227875141342859',
#      'commenter_id': '100049821698002',
#      'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&__tn__=R',
#      'commenter_name': 'Vi',
#      'commenter_meta': None,
#      'comment_text': 'Deene Cao uk đúng',
#      'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#      'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#      'comment_reactors': [{'name': 'Deene Cao',
#        'link': 'https://facebook.com/DeeneCao.Deku?fref=pb',
#        'type': 'like'}],
#      'comment_reactions': {'like': 1},
#      'comment_reaction_count': 1}]},
#   {'comment_id': '407948081484010',
#    'comment_url': 'https://facebook.com/407948081484010',
#    'commenter_id': '100000513709805',
#    'commenter_url': 'https://facebook.com/junerye?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Trung Nguyen',
#    'commenter_meta': 'Fan cứng',
#    'comment_text': 'Phải lấy tên là Aba thay vì Ariel thì đỡ rồi 🐧',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '590340012880086',
#    'comment_url': 'https://facebook.com/590340012880086',
#    'commenter_id': '100015373929835',
#    'commenter_url': 'https://facebook.com/hieeus.136?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Trung Hiếu',
#    'commenter_meta': None,
#    'comment_text': 'Thien Nguyen hắc tiên cá',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 54),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '369096098621435',
#    'comment_url': 'https://facebook.com/369096098621435',
#    'commenter_id': '100054087376697',
#    'commenter_url': 'https://facebook.com/cheng.minh.16?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Minh Cheng',
#    'commenter_meta': None,
#    'comment_text': 'Làm gì có, vai Jasmine cũng bị ấy nữa cơ :))) bản chuyển thể là 1 chuyện chả ai quan tâm còn bản off của Disney thì phải lên án chứ',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '421385506750155',
#    'comment_url': 'https://facebook.com/421385506750155',
#    'commenter_id': '100000013781769',
#    'commenter_url': 'https://facebook.com/ThaoMichelle?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Thảo Thái',
#    'commenter_meta': None,
#    'comment_text': 'Minh Quang ko đẹp thì nói ko đẹp nhg như thế nào mới gọi là đẹp. Its ME :))))',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 38),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Minh Nguỵt',
#      'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 1},
#    'comment_reaction_count': 1,
#    'replies': []},
#   {'comment_id': '743481123409058',
#    'comment_url': 'https://facebook.com/743481123409058',
#    'commenter_id': '100026641873805',
#    'commenter_url': 'https://facebook.com/royizhinnes?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Châu',
#    'commenter_meta': None,
#    'comment_text': 'Chê phim chê vai',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 33),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Minh Nguỵt',
#      'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 1},
#    'comment_reaction_count': 1,
#    'replies': []},
#   {'comment_id': '1241881559983902',
#    'comment_url': 'https://facebook.com/1241881559983902',
#    'commenter_id': '100006990942755',
#    'commenter_url': 'https://facebook.com/profile.php?id=100006990942755&fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Thanh Vân Nguyễn',
#    'commenter_meta': None,
#    'comment_text': 'Nguyễn Phương Phạm Huệ Linh chuẩn ý mình luôn 🙂',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 59),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '1526942897741635',
#    'comment_url': 'https://facebook.com/1526942897741635',
#    'commenter_id': '100080214914902',
#    'commenter_url': 'https://facebook.com/profile.php?id=100080214914902&fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Jordan Albert',
#    'commenter_meta': None,
#    'comment_text': 'Vy Lê thế giới kỳ',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 37),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Đào Hữu Phúc',
#      'link': 'https://facebook.com/profile.php?id=100011314001679&fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 1},
#    'comment_reaction_count': 1,
#    'replies': []},
#   {'comment_id': '567388708498995',
#    'comment_url': 'https://facebook.com/567388708498995',
#    'commenter_id': '100051186218559',
#    'commenter_url': 'https://facebook.com/nhuwys.hydrangeas?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Nguyệt Đảo Huỳnh',
#    'commenter_meta': None,
#    'comment_text': 'Thấy bọn trẩu còn dùng cả n word cơ đấy🤣🤣🤣🤣🤣🤣🤣',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 3),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []},
#   {'comment_id': '476688467804903',
#    'comment_url': 'https://facebook.com/476688467804903',
#    'commenter_id': '100036955745826',
#    'commenter_url': 'https://facebook.com/profile.php?id=100036955745826&fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Nhân Hồ',
#    'commenter_meta': None,
#    'comment_text': 'tiêu chuẩn kép',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#    'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#    'comment_reactors': [{'name': 'Minh Ngọc',
#      'link': 'https://facebook.com/profile.php?id=100022211763212&fref=pb',
#      'type': 'like'},
#     {'name': 'Huyền Huyền',
#      'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#      'type': 'like'}],
#    'comment_reactions': {'like': 2},
#    'comment_reaction_count': 2,
#    'replies': []},
#   {'comment_id': '751027475989581',
#    'comment_url': 'https://facebook.com/751027475989581',
#    'commenter_id': '100010217112703',
#    'commenter_url': 'https://facebook.com/nhiem.h.nguyen?fref=nf&rc=p&refid=52&__tn__=R',
#    'commenter_name': 'Nguyen Huu Nhiem',
#    'commenter_meta': None,
#    'comment_text': 'T thấy đẹp là đẹp',
#    'comment_time': datetime.datetime(2022, 9, 10, 23, 53),
#    'comment_image': None,
#    'comment_reactors': [],
#    'comment_reactions': None,
#    'comment_reaction_count': None,
#    'replies': []}],
#  'reactors': [],
#  'w3_fb_url': 'https://www.facebook.com/usuktimes/posts/621831346134146',
#  'reactions': {'thích': 641,
#   'yêu thích': 151,
#   'haha': 46,
#   'thương thương': 6,
#   'buồn': 13},
#  'reaction_count': 857,
#  'with': None,
#  'page_id': '194884918029862',
#  'sharers': None,
#  'image_id': '621840039466610',
#  'image_ids': ['621840039466610'],
#  'was_live': False,
#  'fetched_time': datetime.datetime(2022, 9, 11, 7, 2, 51, 406591)}

# %%
post_list[0]["comments_full"]
# Out:
# [{'comment_id': '772081764063187',
#   'comment_url': 'https://facebook.com/772081764063187',
#   'commenter_id': '105742761352785',
#   'commenter_url': 'https://facebook.com/Page-comment-dạo-105742761352785/?rc=p&refid=52&__tn__=%7ER',
#   'commenter_name': 'Page comment dạo',
#   'commenter_meta': None,
#   'comment_text': 'Ở đây người ta chê là đi quá xa so với nguyên tác thôi mà chứ đâu có phân biệt gì, còn bà nữ hoàng lên twitter cũng nhiều người chửi kinh chứ đâu phải mỗi người việt',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 6),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Quốc Đạt',
#     'link': 'https://facebook.com/profile.php?id=100010674425336&fref=pb',
#     'type': 'like'},
#    {'name': 'Hiên',
#     'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 2},
#   'comment_reaction_count': 2,
#   'replies': []},
#  {'comment_id': '458444376228586',
#   'comment_url': 'https://facebook.com/458444376228586',
#   'commenter_id': '100084513108521',
#   'commenter_url': 'https://facebook.com/profile.php?id=100084513108521&fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Mưa nào mà hổng tạnh?',
#   'commenter_meta': None,
#   'comment_text': 'T chỉ chê k hợp vai',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 11),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '612147090506524',
#   'comment_url': 'https://facebook.com/612147090506524',
#   'commenter_id': '108450644790868',
#   'commenter_url': 'https://facebook.com/Unknown-cmt-dạo-108450644790868/?rc=p&refid=52&__tn__=%7ER',
#   'commenter_name': 'Unknown cmt dạo',
#   'commenter_meta': None,
#   'comment_text': 'Biết ai bắt đầu mấy cái linh tinh này ko? Bọn phê ph\\\\ hãm loz đấy. Ko hài lòng thì có thể lên án, nhưng lani chọn giở giọng chê bôi shaming racist vđ ra. Bắt nguồn hết từ lũ phê f…ò chứ đâu',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 2),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '455933446283551',
#   'comment_url': 'https://facebook.com/455933446283551',
#   'commenter_id': '100012815145217',
#   'commenter_url': 'https://facebook.com/thanhyen.vo.758?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Võ Nguyễn Thanh Xuân',
#   'commenter_meta': None,
#   'comment_text': 'Yeah chê không đúng với nguyên tác chứ mấy người bodyshaming chỉ dữ dội quá\nDùng từ khó nghe vcl',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Đào Hữu Phúc',
#     'link': 'https://facebook.com/profile.php?id=100011314001679&fref=pb',
#     'type': 'like'},
#    {'name': 'Minh Chauu',
#     'link': 'https://facebook.com/nguyen.m.chau.376?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 2},
#   'comment_reaction_count': 2,
#   'replies': []},
#  {'comment_id': '630888685301129',
#   'comment_url': 'https://facebook.com/630888685301129',
#   'commenter_id': '100069037194802',
#   'commenter_url': 'https://facebook.com/profile.php?id=100069037194802&fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Miyawaki Nako',
#   'commenter_meta': None,
#   'comment_text': 'Thật ra ko có chê màu da, mà là chê nhan sắc của diễn viên',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 1),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Đào Hương Giang',
#     'link': 'https://facebook.com/profile.php?id=100028313640019&fref=pb',
#     'type': 'like'},
#    {'name': 'Lê Thị Bích Trâm',
#     'link': 'https://facebook.com/tram.lethibich.3158?fref=pb',
#     'type': 'like'},
#    {'name': 'Hiên',
#     'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#     'type': 'like'},
#    {'name': 'Huyền Huyền',
#     'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 4},
#   'comment_reaction_count': 4,
#   'replies': []},
#  {'comment_id': '571491394666880',
#   'comment_url': 'https://facebook.com/571491394666880',
#   'commenter_id': '100004012895331',
#   'commenter_url': 'https://facebook.com/HillyN06?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Yến Nguyễn',
#   'commenter_meta': None,
#   'comment_text': 'Chẳng phải thượng đẳng nhưng Ariel là một tượng đài đối với đa số người vì những đặc trưng của ẻm, h live action vứt cmn hết nguyên tác đi kèm theo mấy đứa cmt không mang não thì k toxic k được',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Làng Gốm bÁt TrÀg +',
#     'link': 'https://facebook.com/Làng-Gốm-bÁt-TrÀg--101818822413088/?fref=pb',
#     'type': 'like'},
#    {'name': 'Nguyen Tuan',
#     'link': 'https://facebook.com/profile.php?id=100076185171317&fref=pb',
#     'type': 'like'},
#    {'name': 'Hee Bóng Gồng',
#     'link': 'https://facebook.com/profile.php?id=100073942326570&fref=pb',
#     'type': 'like'},
#    {'name': 'Kim Sángg',
#     'link': 'https://facebook.com/ksr1408?fref=pb',
#     'type': 'like'},
#    {'name': 'Enola Pham',
#     'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#     'type': 'like'},
#    {'name': 'Hiên',
#     'link': 'https://facebook.com/ddoanthuhien?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 6},
#   'comment_reaction_count': 6,
#   'replies': [{'comment_id': '1744341632591813',
#     'comment_url': 'https://facebook.com/1744341632591813',
#     'commenter_id': '100004012895331',
#     'commenter_url': 'https://facebook.com/HillyN06?fref=nf&rc=p&__tn__=R',
#     'commenter_name': 'Yến Nguyễn',
#     'commenter_meta': None,
#     'comment_text': 'Halle thử đóng Tiana xem con dân nó có tung hô bằng zời không 🙂 này cứ nhằm Ariel mà đóng thì ai chẳng cú',
#     'comment_time': datetime.datetime(2022, 9, 10, 23, 12),
#     'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#     'comment_reactors': [{'name': 'Kim Sángg',
#       'link': 'https://facebook.com/ksr1408?fref=pb',
#       'type': 'like'},
#      {'name': 'Enola Pham',
#       'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#       'type': 'like'},
#      {'name': 'Haanh Hoang',
#       'link': 'https://facebook.com/profile.php?id=100018876721453&fref=pb',
#       'type': 'like'}],
#     'comment_reactions': {'like': 3},
#     'comment_reaction_count': 3}]},
#  {'comment_id': '396151842692455',
#   'comment_url': 'https://facebook.com/396151842692455',
#   'commenter_id': '100000111721740',
#   'commenter_url': 'https://facebook.com/rapuzel.wild?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Thơm Donal',
#   'commenter_meta': None,
#   'comment_text': 'Thà đổi tên công chúa đi thì hơn bạn ah, arion hay ariri gì cũng đc, tại sao phải là Ariel, phá nát tuổi thơ của tui , tui ko có kì thi gì nhưng công chúa Ariel trong truyện là cá Koi chứ ko phải cá trắm đen ...',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 1),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Hee Bóng Gồng',
#     'link': 'https://facebook.com/profile.php?id=100073942326570&fref=pb',
#     'type': 'like'},
#    {'name': 'Hạ Nhiên',
#     'link': 'https://facebook.com/profile.php?id=100071038076902&fref=pb',
#     'type': 'like'},
#    {'name': 'Enola Pham',
#     'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#     'type': 'like'},
#    {'name': 'Minh Cheng',
#     'link': 'https://facebook.com/cheng.minh.16?fref=pb',
#     'type': 'like'},
#    {'name': 'Minh Nguỵt',
#     'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#     'type': 'like'},
#    {'name': 'Haanh Hoang',
#     'link': 'https://facebook.com/profile.php?id=100018876721453&fref=pb',
#     'type': 'like'},
#    {'name': 'Huyền Huyền',
#     'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#     'type': 'like'},
#    {'name': 'Yến Nguyễn',
#     'link': 'https://facebook.com/HillyN06?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 8},
#   'comment_reaction_count': 8,
#   'replies': []},
#  {'comment_id': '647996189899519',
#   'comment_url': 'https://facebook.com/647996189899519',
#   'commenter_id': '100070207290574',
#   'commenter_url': 'https://facebook.com/ksr1408?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Kim Sángg',
#   'commenter_meta': None,
#   'comment_text': 'Không đồng tình với những cô cậu body shaming hay pbct,màu da để chửi.Cũng không rõ Bạch Tuyết hay Ariel là người có ngoại hình như thế nào trong bản gốc,cốt truyện gốc mà mng nói.Nhưng đứng ở góc nhìn của toi từ nhỏ tới bây giờ,những bộ phim hay câu chuyện toi được coi thì Bạch Tuyết tóc đen mun bồng bềnh da trắng,nàng tiên cá tóc đỏ mắt sáng da màu sáng(nói thẳng ra là da trắng).Đấy là toi thấy,bây giờ làm phim,hình tượng nhân vật không giống trong tưởng tượng và những gì toi được biết thì toi có quyền không hài lòng và thất vọng.Đọc cmt của một số người bảo vệ quyền của người da màu nhưng nói như kiểu chúng toi kì thị chủng tộc vậy đó.Thất vọng và kì thị nó rất khác biệt mà nhỉ?',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 50),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '5630687016974423',
#   'comment_url': 'https://facebook.com/5630687016974423',
#   'commenter_id': '100015101804474',
#   'commenter_url': 'https://facebook.com/phamtuangian?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Phạm Tuấn Gian',
#   'commenter_meta': None,
#   'comment_text': 'Làm live action theo y bản gốc thì chê nhạt nhẽo, giờ Disney đổi mới thì lại chê k hợp. Mấy má mở bản 2d tự xem đi má',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 19),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '742446810389141',
#   'comment_url': 'https://facebook.com/742446810389141',
#   'commenter_id': '100033077760299',
#   'commenter_url': 'https://facebook.com/annieforabetterlife?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Bình An',
#   'commenter_meta': None,
#   'comment_text': 'Bà này đóng vai tiana của hoàng tử ếch hợp hơn',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 3),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Enola Pham',
#     'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 1},
#   'comment_reaction_count': 1,
#   'replies': []},
#  {'comment_id': '394887972634663',
#   'comment_url': 'https://facebook.com/394887972634663',
#   'commenter_id': '100010265733528',
#   'commenter_url': 'https://facebook.com/vitocvit0601?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Su An',
#   'commenter_meta': None,
#   'comment_text': 'K phải pbct nhưng bả đóng k hợp thật mà, nếu bả vào vai cc tóc xù hay Moana thì đã khác',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 7),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1074976213390468',
#   'comment_url': 'https://facebook.com/1074976213390468',
#   'commenter_id': '100057590401565',
#   'commenter_url': 'https://facebook.com/MKhenh?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Minh Khánh',
#   'commenter_meta': None,
#   'comment_text': 'Mà bên nc ngoài nó chê trước , chê còn thậm tệ hơn , chê từ lúc film mới cast diễn viên r :))',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 56),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '600728248265291',
#   'comment_url': 'https://facebook.com/600728248265291',
#   'commenter_id': '100049821698002',
#   'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Vi',
#   'commenter_meta': None,
#   'comment_text': 'C Ariel ko đẹp thiệt=))',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 5),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Enola Pham',
#     'link': 'https://facebook.com/profile.php?id=100057832975020&fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 1},
#   'comment_reaction_count': 1,
#   'replies': [{'comment_id': '1149511769106636',
#     'comment_url': 'https://facebook.com/1149511769106636',
#     'commenter_id': '100064439176152',
#     'commenter_url': 'https://facebook.com/DeeneCao.Deku?fref=nf&rc=p&__tn__=R',
#     'commenter_name': 'Deene Cao',
#     'commenter_meta': None,
#     'comment_text': 'Vi ???',
#     'comment_time': datetime.datetime(2022, 9, 10, 23, 9),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '430042945658997',
#     'comment_url': 'https://facebook.com/430042945658997',
#     'commenter_id': '100049821698002',
#     'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&__tn__=R',
#     'commenter_name': 'Vi',
#     'commenter_meta': None,
#     'comment_text': 'Deene Cao ???',
#     'comment_time': datetime.datetime(2022, 9, 10, 23, 9),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '479556584185612',
#     'comment_url': 'https://facebook.com/479556584185612',
#     'commenter_id': '100064439176152',
#     'commenter_url': 'https://facebook.com/DeeneCao.Deku?fref=nf&rc=p&__tn__=R',
#     'commenter_name': 'Deene Cao',
#     'commenter_meta': None,
#     'comment_text': 'Vi Không phải là không đẹp chỉ là không hợp vai côg chúa này thôi chứ?',
#     'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#     'comment_image': None,
#     'comment_reactors': [],
#     'comment_reactions': None,
#     'comment_reaction_count': None},
#    {'comment_id': '1227875141342859',
#     'comment_url': 'https://facebook.com/1227875141342859',
#     'commenter_id': '100049821698002',
#     'commenter_url': 'https://facebook.com/vivibyred?fref=nf&rc=p&__tn__=R',
#     'commenter_name': 'Vi',
#     'commenter_meta': None,
#     'comment_text': 'Deene Cao uk đúng',
#     'comment_time': datetime.datetime(2022, 9, 10, 23, 10),
#     'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#     'comment_reactors': [{'name': 'Deene Cao',
#       'link': 'https://facebook.com/DeeneCao.Deku?fref=pb',
#       'type': 'like'}],
#     'comment_reactions': {'like': 1},
#     'comment_reaction_count': 1}]},
#  {'comment_id': '407948081484010',
#   'comment_url': 'https://facebook.com/407948081484010',
#   'commenter_id': '100000513709805',
#   'commenter_url': 'https://facebook.com/junerye?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Trung Nguyen',
#   'commenter_meta': 'Fan cứng',
#   'comment_text': 'Phải lấy tên là Aba thay vì Ariel thì đỡ rồi 🐧',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '590340012880086',
#   'comment_url': 'https://facebook.com/590340012880086',
#   'commenter_id': '100015373929835',
#   'commenter_url': 'https://facebook.com/hieeus.136?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Trung Hiếu',
#   'commenter_meta': None,
#   'comment_text': 'Thien Nguyen hắc tiên cá',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 54),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '369096098621435',
#   'comment_url': 'https://facebook.com/369096098621435',
#   'commenter_id': '100054087376697',
#   'commenter_url': 'https://facebook.com/cheng.minh.16?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Minh Cheng',
#   'commenter_meta': None,
#   'comment_text': 'Làm gì có, vai Jasmine cũng bị ấy nữa cơ :))) bản chuyển thể là 1 chuyện chả ai quan tâm còn bản off của Disney thì phải lên án chứ',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '421385506750155',
#   'comment_url': 'https://facebook.com/421385506750155',
#   'commenter_id': '100000013781769',
#   'commenter_url': 'https://facebook.com/ThaoMichelle?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Thảo Thái',
#   'commenter_meta': None,
#   'comment_text': 'Minh Quang ko đẹp thì nói ko đẹp nhg như thế nào mới gọi là đẹp. Its ME :))))',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 38),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Minh Nguỵt',
#     'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 1},
#   'comment_reaction_count': 1,
#   'replies': []},
#  {'comment_id': '743481123409058',
#   'comment_url': 'https://facebook.com/743481123409058',
#   'commenter_id': '100026641873805',
#   'commenter_url': 'https://facebook.com/royizhinnes?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Châu',
#   'commenter_meta': None,
#   'comment_text': 'Chê phim chê vai',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 33),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Minh Nguỵt',
#     'link': 'https://facebook.com/profile.php?id=100022048520273&fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 1},
#   'comment_reaction_count': 1,
#   'replies': []},
#  {'comment_id': '1241881559983902',
#   'comment_url': 'https://facebook.com/1241881559983902',
#   'commenter_id': '100006990942755',
#   'commenter_url': 'https://facebook.com/profile.php?id=100006990942755&fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Thanh Vân Nguyễn',
#   'commenter_meta': None,
#   'comment_text': 'Nguyễn Phương Phạm Huệ Linh chuẩn ý mình luôn 🙂',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 59),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1526942897741635',
#   'comment_url': 'https://facebook.com/1526942897741635',
#   'commenter_id': '100080214914902',
#   'commenter_url': 'https://facebook.com/profile.php?id=100080214914902&fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Jordan Albert',
#   'commenter_meta': None,
#   'comment_text': 'Vy Lê thế giới kỳ',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 37),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Đào Hữu Phúc',
#     'link': 'https://facebook.com/profile.php?id=100011314001679&fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 1},
#   'comment_reaction_count': 1,
#   'replies': []},
#  {'comment_id': '567388708498995',
#   'comment_url': 'https://facebook.com/567388708498995',
#   'commenter_id': '100051186218559',
#   'commenter_url': 'https://facebook.com/nhuwys.hydrangeas?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Nguyệt Đảo Huỳnh',
#   'commenter_meta': None,
#   'comment_text': 'Thấy bọn trẩu còn dùng cả n word cơ đấy🤣🤣🤣🤣🤣🤣🤣',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 3),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '476688467804903',
#   'comment_url': 'https://facebook.com/476688467804903',
#   'commenter_id': '100036955745826',
#   'commenter_url': 'https://facebook.com/profile.php?id=100036955745826&fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Nhân Hồ',
#   'commenter_meta': None,
#   'comment_text': 'tiêu chuẩn kép',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 0),
#   'comment_image': 'https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AT_qbKYI6IncUXkLfSdqrKOqv1pHI_hCEdutUDSRxviP2w&oe=63218CF9&_nc_sid=55e238',
#   'comment_reactors': [{'name': 'Minh Ngọc',
#     'link': 'https://facebook.com/profile.php?id=100022211763212&fref=pb',
#     'type': 'like'},
#    {'name': 'Huyền Huyền',
#     'link': 'https://facebook.com/huyenhuyen811?fref=pb',
#     'type': 'like'}],
#   'comment_reactions': {'like': 2},
#   'comment_reaction_count': 2,
#   'replies': []},
#  {'comment_id': '751027475989581',
#   'comment_url': 'https://facebook.com/751027475989581',
#   'commenter_id': '100010217112703',
#   'commenter_url': 'https://facebook.com/nhiem.h.nguyen?fref=nf&rc=p&refid=52&__tn__=R',
#   'commenter_name': 'Nguyen Huu Nhiem',
#   'commenter_meta': None,
#   'comment_text': 'T thấy đẹp là đẹp',
#   'comment_time': datetime.datetime(2022, 9, 10, 23, 53),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []}]

# %%
print(type(post_list[0]))
x = post_list[0].keys()
x
# Out:
# <class 'dict'>
# dict_keys(['post_id', 'text', 'post_text', 'shared_text', 'original_text', 'time', 'timestamp', 'image', 'image_lowquality', 'images', 'images_description', 'images_lowquality', 'images_lowquality_description', 'video', 'video_duration_seconds', 'video_height', 'video_id', 'video_quality', 'video_size_MB', 'video_thumbnail', 'video_watches', 'video_width', 'likes', 'comments', 'shares', 'post_url', 'link', 'links', 'user_id', 'username', 'user_url', 'is_live', 'factcheck', 'shared_post_id', 'shared_time', 'shared_user_id', 'shared_username', 'shared_post_url', 'available', 'comments_full', 'reactors', 'w3_fb_url', 'reactions', 'reaction_count', 'with', 'page_id', 'sharers', 'image_id', 'image_ids', 'was_live', 'fetched_time'])

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns = [])
# Start to collect Facebook post data by facebook_scraper library
for post in post_list:
    post_entry = post
    fb_post_df = pd.DataFrame.from_dict(post_entry, orient='index')
    fb_post_df = fb_post_df.transpose()
    post_df_full = post_df_full.append(fb_post_df)
    print(post['post_id']+' get')
# Out:
# 621831346134146 get
# 621301309520483 get
# 620203652963582 get
# 615225000128114 get
# 615210750129539 get
# 613406806976600 get
# 612103410440273 get
# 611010443882903 get
# 610926020558012 get
# 610879620562652 get
# 610812033902744 get
# 610799680570646 get
# 609491260701488 get
# 608861424097805 get
# 608764747440806 get
# 608576227459658 get
# 607849110865703 get
# 607722667545014 get
# 607711940879420 get
# 607701647547116 get
# 607182934265654 get
# 607133800937234 get
# 606879137629367 get
# 606829914300956 get
# 606477141002900 get
# 606358687681412 get
# 606297714354176 get
# 606295261021088 get
# 605748641075750 get
# 604922207825060 get
# 605198184464129 get
# 604916151158999 get
# 604907457826535 get
# 604897871160827 get
# 604777861172828 get
# 604748764509071 get
# 604690101181604 get
# 604605384523409 get
# 604565201194094 get
# 604525134531434 get
# 604208387896442 get
# 604216427895638 get
# 604044581246156 get
# 603873054596642 get
# 603847671265847 get
# 603276737989607 get
# 603096161340998 get
# 603081761342438 get
# 603062644677683 get
# 603052784678669 get
# 603033658013915 get
# 602321368085144 get
# 602295028087778 get
# 600949048222376 get
# 597964541854160 get
# 597206998596581 get
# 594204042230210 get
# 594190782231536 get
# 593389255645022 get
# 592688582381756 get
# 592683855715562 get
# 592676935716254 get
# 592309135753034 get
# 592087019108579 get
# 591941952456419 get
# 591932659124015 get
# 589793119337969 get
# 589758902674724 get
# 589737809343500 get
# 589730432677571 get
# 589718436012104 get
# 1198012301050447 get
# 1194515368066807 get
# 1193789411472736 get
# 1193595351492142 get
# 1192297378288606 get
# 1192269951624682 get
# 1189157545269256 get
# 1186623612189316 get
# 1186346415550369 get
# 1185839802267697 get
# 1185365382315139 get
# 1184981459020198 get
# 1184111329107211 get
# 1183933189125025 get
# 1183862519132092 get
# 1183829159135428 get
# 1183091089209235 get
# 1182382005946810 get
# 1180672422784435 get
# 1180540796130931 get
# 1180403216144689 get
# 1179924559525888 get
# 1179569936228017 get
# 1179192886265722 get
# 1178552979663046 get
# 1177737839744560 get
# 1177414076443603 get
# 1177254746459536 get
# 1174643956720615 get

# %%
post_df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 0
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        100 non-null    object
#  1   text                           100 non-null    object
#  2   post_text                      100 non-null    object
#  3   shared_text                    100 non-null    object
#  4   original_text                  0 non-null      object
#  5   time                           100 non-null    datetime64[ns]
#  6   timestamp                      100 non-null    object
#  7   image                          90 non-null     object
#  8   image_lowquality               100 non-null    object
#  9   images                         100 non-null    object
#  10  images_description             100 non-null    object
#  11  images_lowquality              100 non-null    object
#  12  images_lowquality_description  100 non-null    object
#  13  video                          4 non-null      object
#  14  video_duration_seconds         0 non-null      object
#  15  video_height                   0 non-null      object
#  16  video_id                       4 non-null      object
#  17  video_quality                  0 non-null      object
#  18  video_size_MB                  0 non-null      object
#  19  video_thumbnail                4 non-null      object
#  20  video_watches                  0 non-null      object
#  21  video_width                    0 non-null      object
#  22  likes                          0 non-null      object
#  23  comments                       100 non-null    object
#  24  shares                         100 non-null    object
#  25  post_url                       100 non-null    object
#  26  link                           2 non-null      object
#  27  links                          100 non-null    object
#  28  user_id                        100 non-null    object
#  29  username                       100 non-null    object
#  30  user_url                       100 non-null    object
#  31  is_live                        100 non-null    object
#  32  factcheck                      0 non-null      object
#  33  shared_post_id                 0 non-null      object
#  34  shared_time                    0 non-null      object
#  35  shared_user_id                 0 non-null      object
#  36  shared_username                0 non-null      object
#  37  shared_post_url                0 non-null      object
#  38  available                      100 non-null    object
#  39  comments_full                  100 non-null    object
#  40  reactors                       100 non-null    object
#  41  w3_fb_url                      100 non-null    object
#  42  reactions                      100 non-null    object
#  43  reaction_count                 100 non-null    object
#  44  with                           0 non-null      object
#  45  page_id                        100 non-null    object
#  46  sharers                        0 non-null      object
#  47  image_id                       82 non-null     object
#  48  image_ids                      100 non-null    object
#  49  was_live                       100 non-null    object
#  50  fetched_time                   100 non-null    datetime64[ns]
#  51  video_ids                      7 non-null      object
#  52  videos                         7 non-null      object
# dtypes: datetime64[ns](2), object(51)
# memory usage: 42.2+ KB

# %%
# hiển thị 10 post đầu tiên
post_df_full.head(10)
# Out:
#            post_id                                               text  \
# 0  621831346134146  Một số người Việt: chê cười Anh Mỹ phân biệt c...
# 0  621301309520483                Quá trời md rồiii\n\nCre: Pop Gurlz
# 0  620203652963582  Nghỉ chơi Twitter và Tiktok trong những ngày s...
# 0  615225000128114  #REVIEW NOPE - JORDAN PEELE (2022)\n\nĐÂY CÓ T...
# 0  615210750129539  Tỉ lệ thắng của Serena Williams thực sự kinh k...
# 0  613406806976600  Nàng Bạch Tuyết Rachel Zegler khoe giọng hát c...
# 0  612103410440273  Hình ảnh người vợ up str chăm chỉ cày nhạc cho...
# 0  611010443882903  Taylor Swift ở VMAs 2009 và Taylor Swift ở VMA...
# 0  610926020558012  UMGGG!!! ALBUM MỚI CỦA TAYLOR SWIFT SẼ PHÁT HÀ...
# 0  610879620562652  VMAs xác nhận BTS là nghệ sĩ chiến thắng giải ...
#
#                                            post_text shared_text  \
# 0  Một số người Việt: chê cười Anh Mỹ phân biệt c...
# 0                Quá trời md rồiii\n\nCre: Pop Gurlz
# 0  Nghỉ chơi Twitter và Tiktok trong những ngày s...
# 0  #REVIEW NOPE - JORDAN PEELE (2022)\n\nĐÂY CÓ T...
# 0  Tỉ lệ thắng của Serena Williams thực sự kinh k...
# 0  Nàng Bạch Tuyết Rachel Zegler khoe giọng hát c...
# 0  Hình ảnh người vợ up str chăm chỉ cày nhạc cho...
# 0  Taylor Swift ở VMAs 2009 và Taylor Swift ở VMA...
# 0  UMGGG!!! ALBUM MỚI CỦA TAYLOR SWIFT SẼ PHÁT HÀ...
# 0  VMAs xác nhận BTS là nghệ sĩ chiến thắng giải ...
#
#   original_text                time   timestamp  \
# 0          None 2022-09-11 05:33:48  1662874428
# 0          None 2022-09-10 15:22:55  1662823375
# 0          None 2022-09-09 11:19:12  1662722352
# 0          None 2022-09-03 05:19:23  1662182363
# 0          None 2022-09-03 04:48:58  1662180538
# 0          None 2022-09-01 04:32:11  1662006731
# 0          None 2022-08-30 14:25:47  1661869547
# 0          None 2022-08-29 08:53:23  1661763203
# 0          None 2022-08-29 05:41:17  1661751677
# 0          None 2022-08-29 04:00:26  1661745626
#
#                                                image  \
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0                                               None
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0                                               None
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
#
#                                     image_lowquality  \
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/m1/v/t6...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t15.5...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
# 0  https://scontent.ftir6-1.fna.fbcdn.net/v/t39.3...
#
#                                               images  ... reaction_count  \
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...            857
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...             55
# 0                                                 []  ...           1192
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...            150
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...           5685
# 0                                                 []  ...             88
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...            407
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...            434
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...           1388
# 0  [https://scontent.ftir6-1.fna.fbcdn.net/v/t39....  ...           1299
#
#    with          page_id sharers         image_id          image_ids was_live  \
# 0  None  194884918029862    None  621840039466610  [621840039466610]    False
# 0  None  194884918029862    None  621301116187169  [621301116187169]    False
# 0  None  194884918029862    None             None                 []    False
# 0  None  194884918029862    None  615223286794952  [615223286794952]    False
# 0  None  194884918029862    None  615206806796600  [615206806796600]    False
# 0  None  194884918029862    None             None                 []    False
# 0  None  194884918029862    None  612103307106950  [612103307106950]    False
# 0  None  194884918029862    None  611010397216241  [611010397216241]    False
# 0  None  194884918029862    None  610925947224686  [610925947224686]    False
# 0  None  194884918029862    None  610879557229325  [610879557229325]    False
#
#                 fetched_time video_ids videos
# 0 2022-09-11 07:02:51.406591       NaN    NaN
# 0 2022-09-11 07:03:11.154461       NaN    NaN
# 0 2022-09-11 07:03:13.923436       NaN    NaN
# 0 2022-09-11 07:03:49.814842       NaN    NaN
# 0 2022-09-11 07:03:56.424621       NaN    NaN
# 0 2022-09-11 07:04:15.276337       NaN    NaN
# 0 2022-09-11 07:04:19.444836       NaN    NaN
# 0 2022-09-11 07:04:25.821633       NaN    NaN
# 0 2022-09-11 07:04:30.391253       NaN    NaN
# 0 2022-09-11 07:04:42.939608       NaN    NaN
#
# [10 rows x 53 columns]

# %% [markdown]
# # lưu file

# %%
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(FOLDER_PATH + FANPAGE_LINK + ".xlsx", index=False)
print(path)
# Out:
# /content/drive/MyDrive/Tài liệu năm 4/kì 1/NMKHDL/kiemtra/usuktimes.xlsx

# %%
# importing library
import numpy as np
# converting list to array
arr = np.array(post_list)

# %%
path1=FOLDER_PATH + FANPAGE_LINK + ".npy"
np.save(path1, arr)    # .npy extension is added if not given
print(path1)
# Out:
# /content/drive/MyDrive/Tài liệu năm 4/kì 1/NMKHDL/kiemtra/usuktimes.npy
